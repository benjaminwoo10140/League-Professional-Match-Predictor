# %%
import pandas as pd
print(pd.__version__)

# %%
df = pd.read_csv('../2026_LoL_esports_match_data_from_OraclesElixir.csv')
df.shape

# %%
df.describe()

# %%
df.shape

# %%
df.columns.tolist()
df.head()

# %%
df.sample(10)

# %%
df.columns.tolist()

# %%
df.describe()

# %%
df.info()

# %%
df['league'].unique()

# %%
df['gameid'].nunique()

# %%
df.describe()
df.info()

# %%
df.describe()

# %%
fst_df = df[df['league'] == 'FST']
fst_df

# %%
fst_df.shape

# %%
fst_df['gameid'].unique()

# %%
fst_df['gameid'].nunique()

# %%
fst_df.head(25)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
fst_df

# %%
df.isnull().sum().sort_values(ascending=False).head(20)

# %%
df['dragons (type unknown)'].isnull().sum()

# %%
df = df.drop(columns=['dragons (type unknown)'])

# %%
df = df.drop(columns=['url'])

# %%
df.isnull().sum().sort_values(ascending=False).head(20)

# %%
df = df.drop(columns=['atakhans'])

# %%
df.columns.tolist()

# %%
df['playerid'].sample()

# %%
df['playerid'].sample(5)

# %%
df = df.drop(columns=['playerid'])

# %%
df['datacompleteness'].sample(100)

# %%
df['datacompleteness'].unique()

# %%
df['datacompleteness'].value_counts()

# %%
df = df[df['datacompleteness'] == 'complete']

# %%
df.columns.tolist()

# %%
df.info()

# %%
fst_df.info()

# %%
fst_df.sample(15)

# %%
fst_df = df[df['league'] == 'FST']
fst_df

# %%
fst_df.info()

# %%
fst_df.sample(540)

# %%
df['result'].unique()

# %%
df.isnull().sum().sort_values(ascending=False).head(20)

# %%
df.columns.tolist()

# %%
fst_df

# %%
df.sample(10)

# %%
fst_df = df[df['league'] == 'FST']

# %%
fst_df

# %%
df['playoffs'].unique()

# %%
df['playoffs'].value_counts()

# %%
df.sample(15)

# %%
df = df.drop(columns = 'playoffs')

# %%
df.sample(10)

# %%
df = df.drop(columns='datacompleteness')

# %%
df.columns.tolist()

# %%
df['year'].nunique()

# %%
df['year'].unique()

# %%
df = df.drop(columns='year')

# %%
df.sample(15)

# %%
df

# %%
df = df.reset_index(drop=True)

# %%
df

# %%
df.columns.tolist()

# %%
df = df.drop(columns='split')

# %%
df.sample(15)

# %%
df['monsterkillsownjungle'].unique()

# %%
df['monsterkillsenemyjungle'].unique()

# %%
df['monsterkillsownjungle'].isnull().all()

# %%
df['monsterkillsenemyjungle'].isnull().all()

# %%
df = df.drop(columns=['monsterkillsenemyjungle', 'monsterkillsownjungle'])

# %%
df.columns.tolist()

# %%
df[df['game'] == 5]

# %%
df.groupby('teamid')['teamname'].nunique().value_counts()

# %%
df = df.drop(columns='teamid')

# %%
df[df['game'] == 5].sample(15)

# %%
fst_df = df[df["league"] == 'FST']
fst_df.sample(15)
